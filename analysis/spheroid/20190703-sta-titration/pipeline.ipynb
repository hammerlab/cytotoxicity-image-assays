# %% [markdown]
# ## STA Titration Spheroid Quantification Pipeline

# %%
# Params
exp_name = None
output_dir = None
raw_dir = None

# %%
# # Debug
# exp_name = 'sta-00.500-20um-s-XY01'
# output_dir = '/lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00'
# raw_dir = '/lab/data/spheroid/20190703-sta-titration/raw/05uMsta-20um-grids/XY01'

# %%
for v in ['exp_name', 'output_dir', 'raw_dir']:
    assert globals()[v], '"{}" must be set'.format(v)

# %%
# %matplotlib inline
# %load_ext dotenv
# %dotenv env.sh
# %run source/utils.py
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import os.path as osp
import tqdm
import collections
from centrosome import propagate
from scipy import ndimage as ndi
from skimage import util, morphology, transform, exposure, filters, feature, segmentation
from skimage import io as sk_io
from cytokit import io as ck_io
from cytokit import config as ck_config
from cytokit.cytometry.cytometer import CytometerBase
from cytokit.utils import ij_utils
from cytokit.function import data as ck_data
from cytokit.function import core as ck_core
from cytokit.ops import tile_generator, cytometry, tile_crop
from cytokit.image.ops import describe
from cytokit.exec import ilastik 
matplotlib.rc('image', cmap='gray')

# %%
df = pd.read_csv('experiments.csv')
df = df[df['name'] == exp_name]
assert len(df) == 1, 'Found {} rows for experiment {}'.format(len(df), exp_name)
df
# Out:
#                      name             conf                 dir  grid  n_ch  \
# 6  sta-00.500-20um-s-XY01  experiment.yaml  05uMsta-20um-grids  XY01     3
#
#    n_tiles  n_z               cond  z_pitch
# 6       27    7  sta-00.500-20um-s      200

# %%
cyto_dir = osp.join(output_dir, 'cytometry')
cyto_dir
# Out:
# '/lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00/cytometry'

# %%
ilastik_proj = os.environ['EXP_SPHEROID_ILASTIK_PRJ']
ilastik_proj
# Out:
# '/lab/data/spheroid/ilastik/mc38-co-culture/project/20190822-co-culture-maxz-bf-20x-25s.ilp'

# %%
config = ck_config.load(osp.join(output_dir, 'config'))
config.register_environment()
config
# Out:
# {'environment': {'path_formats': "get_default_path_formats('1_XY01_{tile:05d}_Z{z:03d}_CH{channel:d}.tif')"}, 'processor': {'tile_generator': {'raw_file_type': 'keyence_mixed'}, 'cytometry': {'nuclei_channel_name': 'HOECHST', 'quantification_params': {'nucleus_intensity': True, 'morphology_features': False, 'cell_graph': False}}, 'best_focus': {'channel': 'HOECHST'}, 'args': {'run_cytometry': True, 'run_deconvolution': False, 'gpus': [0, 1], 'run_best_focus': True, 'run_spectral_unmixing': False}, 'deconvolution': {'n_iter': 10, 'channels': ['HOECHST', 'SYTOX'], 'scale_factor': 0.75}}, 'name': 'sta-00.500-20um-s-XY01', 'date': '2019-07-03 00:00:00', 'acquisition': {'lateral_resolution': 377.442, 'per_cycle_channel_names': ['Cy5', 'BF', 'DAPI'], 'region_height': 9, 'objective_type': 'air', 'tile_overlap_y': 432, 'tile_height': 1008, 'emission_wavelengths': [670, 425, 425], 'num_cycles': 1, 'tile_width': 1344, 'tile_overlap_x': 576, 'channel_names': ['SYTOX', 'BF', 'HOECHST'], 'axial_resolution': 20000.0, 'region_width': 3, 'region_names': ['Region1'], 'tiling_mode': 'snake', 'magnification': 20, 'num_z_planes': 7, 'numerical_aperture': 0.75}, 'analysis': [{'aggregate_cytometry_statistics': {'mode': 'best_z_plane'}}, {'cellprofiler_quantification': {'export_db': True, 'export_csv': True}}], 'operator': [{'extract': {'name': 'best_z_segm', 'channels': ['proc_HOECHST', 'proc_BF', 'proc_SYTOX', 'cyto_cell_boundary']}}, {'montage': {'name': 'best_z_segm', 'extract_name': 'best_z_segm'}}]}

# %% [markdown]
# ### Load All Images

# %%
tiles = get_tiles(config, raw_dir)
len(tiles)
# Out:
# 100%|██████████| 27/27 [01:14<00:00,  2.69s/it]
# 27

# %%
img_mtg = ck_core.montage([t[0] for t in tiles], config)
img_mtg.shape
# Out:
# (1, 7, 3, 9072, 4032)

# %% [markdown]
# ### Create max-z BF for spheroid segmentation

# %%
def get_maxz_projection(img_mtg):
    img = img_mtg[0, :, config.channel_names.index('BF')]
    img = util.img_as_float(img)
    img = util.invert(img)
    img = img.max(axis=0)
    # The target scale for BF segmentation is 25% of original 1440x1920 images
    img = transform.rescale(img, .25, anti_aliasing=True, multichannel=False, mode='constant', preserve_range=True)
    assert 0 <= img.min() <= img.max() <= 1
    img = exposure.rescale_intensity(img, in_range=(0, 1), out_range=np.uint8).astype(np.uint8)
    return img

# %%
img_bf_maxz = get_maxz_projection(img_mtg)
describe(img_bf_maxz)
# Out:
# {'bytes': 2286144,
#  'max': 224,
#  'mean': 80.29806215181546,
#  'min': 37,
#  'shape': (2268, 1008),
#  'type': 'uint8'}

# %%
plt.imshow(img_bf_maxz)
plt.gcf().set_size_inches(6, 12)

# %% [markdown]
# ### Spheroid Segmentation

# %%
def get_spheroid_probabilities(img, print_command=False, print_logs=False):
    export_source = 'Probabilities'
    input_path = osp.join(cyto_dir, 'ilastik', 'R001.BF.input.tif')
    output_path = osp.join(cyto_dir, 'ilastik', 'R001.BF.output.tif')
    os.makedirs(osp.dirname(input_path), exist_ok=True)
    sk_io.imsave(input_path, img)
    pres = ilastik.CLI.classify(ilastik_proj, input_path, output_path, export_source=export_source)
    if print_command:
        print('COMMAND: {}\n'.format(' '.join(pres.args)))
    if print_logs:
        print('STDOUT:\n{}'.format(pres.stdout.decode('utf-8')))
        print('STDERR:\n{}'.format(pres.stderr.decode('utf-8')))
    img = sk_io.imread(output_path)
    # Ilastik result is multi-channel image with channels in order of annotated class 
    # in project; assume first channel is class of interest and extract it here:
    assert img.ndim == 3, 'Expecting 2D image, got shape {}'.format(img.shape)
    img = img[..., 0]
    return img

# %%
img_proba = get_spheroid_probabilities(img_bf_maxz, print_command=False, print_logs=False)
describe(img_proba)
# Out:
# COMMAND: /lab/apps/ilastik/run_ilastik.sh --headless --output_filename_format=/lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00/cytometry/ilastik/R001.BF.output.tif --project=/lab/data/spheroid/ilastik/mc38-co-culture/project/20190822-co-culture-maxz-bf-20x-25s.ilp --export_source=Probabilities --output_format=tif --export_dtype=float32 /lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00/cytometry/ilastik/R001.BF.input.tif
#
# STDOUT:
# INFO lazyflow.operators.filterOperators: Using fast filters.
# INFO ilastik_main: Starting ilastik from "/lab/apps/ilastik-1.3.2-Linux".
# Starting ilastik from "/lab/apps/ilastik-1.3.2-Linux".
# INFO ilastik.shell.projectManager: Opening Project: /lab/data/spheroid/ilastik/mc38-co-culture/project/20190822-co-culture-maxz-bf-20x-25s.ilp
# INFO ilastik.workflows.pixelClassification.pixelClassificationWorkflow: Beginning Batch Processing
# INFO ilastik.applets.batchProcessing.batchProcessingApplet: Exporting to /lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00/cytometry/ilastik/R001.BF.output.tif
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per pixel is 260.0B * safety factor (2.0)
# INFO lazyflow.utility.bigRequestStreamer: determining blockshape assuming available_ram is 46.4GiB, split between 8 threads
# INFO lazyflow.utility.bigRequestStreamer: Chose blockshape: (2268, 1008, 2)
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per block is 1.1GiB
# DEBUG lazyflow.operators.classifierOperators: Features took 1.8534350000000002 seconds, Prediction took 3.489488 seconds for roi: [0, 0, 0] : [2268, 1008, 2]
# INFO ilastik.workflows.pixelClassification.pixelClassificationWorkflow: Completed Batch Processing
#
# STDERR:
# Warning: Ignoring your non-empty LD_LIBRARY_PATH
# WARNING __init__.py(11): UserWarning: init: Could not import tiktorch classifier
# WARNING 2019-09-24 20:58:56,693 opConservationTracking 8840 140436301842176 Could not find any ILP solver
# WARNING 2019-09-24 20:58:56,703 opStructuredTracking 8840 140436301842176 Could not find any ILP solver
# WARNING 2019-09-24 20:58:56,705 structuredTrackingWorkflow 8840 140436301842176 Could not find any learning solver. Tracking will use flow-based solver (DPCT). Learning for tracking will be disabled!
# WARNING stype.py(181): UserWarning: ArrayLike.isCompatible: FIXME here
# {'bytes': 9144576,
#  'max': 1.0,
#  'mean': 0.086006254,
#  'min': 0.0,
#  'shape': (2268, 1008),
#  'type': 'float32'}

# %%
plt.imshow(img_proba)
plt.gcf().set_size_inches(6, 12)

# %%
def get_spheroid_mask(img, low=.5, high=.8, sigma=10):
    img = filters.gaussian(img, sigma=sigma)
    img = filters.apply_hysteresis_threshold(img, low, high)
    img = ndi.binary_fill_holes(img)
    return img

def get_spheroid_objects(img_segment, img_mask, min_peak_distance=16, regularization=.001):
    assert 0 <= img_segment.min() <= img_segment.max() <= 1
    img_dist = ndi.distance_transform_edt(img_mask)
    img_pk = feature.peak_local_max(img_dist, min_distance=min_peak_distance, indices=False)
    img_pk = morphology.label(img_pk)
    img_obj, _ = propagate.propagate(img_segment, img_pk, img_mask, regularization)
    return img_obj

# %%
img_mask = get_spheroid_mask(img_proba)
img_obj = get_spheroid_objects(util.img_as_float(img_bf_maxz), img_mask)

# Upsample to original size
img_obj = transform.resize(
    img_obj, img_mtg.shape[-2:], order=0, mode='constant', 
    anti_aliasing=False, preserve_range=True
).astype(img_obj.dtype)
assert img_obj.shape[-2:] == img_mtg.shape[-2:]
describe(img_obj)
# Out:
# {'bytes': 146313216,
#  'max': 46,
#  'mean': 1.357417555499566,
#  'min': 0,
#  'shape': (9072, 4032),
#  'type': 'int32'}

# %%
plt.imshow(img_obj, cmap=rand_cmap(1))
plt.gcf().set_size_inches(6, 12)

# %%
df_sph = CytometerBase.quantify(
    # Quantify averages over z channels 
    img_mtg.mean(axis=1)[np.newaxis], 
    # Duplicate spheroid body as center 
    np.stack([img_obj]*2)[np.newaxis],
    channel_names=config.channel_names,
    nucleus_intensity=False
)
df_sph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 19 columns):
# id                 46 non-null int64
# x                  46 non-null float64
# y                  46 non-null float64
# z                  46 non-null int64
# cm:circularity     46 non-null float64
# cm:diameter        46 non-null float64
# cm:perimeter       46 non-null float64
# cm:size            46 non-null int64
# cm:solidity        46 non-null float64
# nm:circularity     46 non-null float64
# nm:diameter        46 non-null float64
# nm:perimeter       46 non-null float64
# nm:size            46 non-null int64
# nm:solidity        46 non-null float64
# cb:on_border       46 non-null int64
# nb:on_border       46 non-null int64
# ci:SYTOX:mean      46 non-null float64
# ci:BF:mean         46 non-null float64
# ci:HOECHST:mean    46 non-null float64
# dtypes: float64(13), int64(6)
# memory usage: 6.9 KB

# %%
# Export spheroid stats
path = osp.join(output_dir, 'cytometry', 'data.spheroid.csv')
df_sph.to_csv(path, index=False)
path
# Out:
# '/lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00/cytometry/data.spheroid.csv'

# %% [markdown]
# ### Cell Segmentation

# %%
cyto_op = cytometry.Cytometry2D(config, z_plane='all').initialize()
# Out:
# Using TensorFlow backend.

# %%
assert config.channel_names == cyto_op.quantification_params['channel_names']
cyto_op.quantification_params['channel_names']
# Out:
# ['SYTOX', 'BF', 'HOECHST']

# %%
cyto_op.quantification_params['channel_names'] = cyto_op.quantification_params['channel_names'] + ['SPHEROID']
cyto_op.quantification_params['channel_names']
# Out:
# ['SYTOX', 'BF', 'HOECHST', 'SPHEROID']

# %%
obj_map = {ti: tile for tile, ti in ck_core.unmontage(img_obj, config, strict=True)}

# %%
def repeat(img, nz):
    assert img.ndim == 2
    return np.repeat(img[np.newaxis, np.newaxis, np.newaxis], nz, axis=1)

# %%
repeat(list(obj_map.values())[0], config.n_z_planes).shape
# Out:
# (1, 7, 1, 1008, 1344)

# %%
def get_cell_segmentation():
    res = collections.OrderedDict()
    ct = 0
    for tile, tile_index in ck_core.unmontage(img_mtg, config, strict=True):
        # Get mask for spheroids (repeated along z dimension) and append to tile (as new channel on end)
        mask_tile = repeat(obj_map[tile_index] > 0, config.n_z_planes)
        tile = np.concatenate((tile, mask_tile.astype(tile.dtype)), axis=2)
        # Run segmentation and quantification
        tile, (tseg, tstat) = cyto_op.run(tile)
        res[tile_index] = tile, tseg, tstat
    return res
seg_res = get_cell_segmentation()

# %% [markdown]
# ## Export

# %% [markdown]
# #### Tile Results

# %%
# Export per-tile results
for tile_index in seg_res:
    tile, tseg, tstat = seg_res[tile_index]
    paths = cyto_op.save(tile_index, output_dir, (tseg, tstat), compress=0)
    print('Saved cytometry data to paths ', paths)
# tags = ij_utils.get_slice_label_tags(['BF', 'MASK', 'BOUNDARY'] + CFLRO + CFLRO_QUANT)
# ck_io.save_tile(path, img_ext, config=config, infer_labels=False, extratags=tags)
# Out:
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y001.tif', 'cytometry/statistics/R001_X001_Y001.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y001.tif', 'cytometry/statistics/R001_X002_Y001.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y001.tif', 'cytometry/statistics/R001_X003_Y001.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y002.tif', 'cytometry/statistics/R001_X003_Y002.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y002.tif', 'cytometry/statistics/R001_X002_Y002.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y002.tif', 'cytometry/statistics/R001_X001_Y002.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y003.tif', 'cytometry/statistics/R001_X001_Y003.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y003.tif', 'cytometry/statistics/R001_X002_Y003.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y003.tif', 'cytometry/statistics/R001_X003_Y003.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y004.tif', 'cytometry/statistics/R001_X003_Y004.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y004.tif', 'cytometry/statistics/R001_X002_Y004.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y004.tif', 'cytometry/statistics/R001_X001_Y004.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y005.tif', 'cytometry/statistics/R001_X001_Y005.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y005.tif', 'cytometry/statistics/R001_X002_Y005.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y005.tif', 'cytometry/statistics/R001_X003_Y005.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y006.tif', 'cytometry/statistics/R001_X003_Y006.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y006.tif', 'cytometry/statistics/R001_X002_Y006.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y006.tif', 'cytometry/statistics/R001_X001_Y006.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y007.tif', 'cytometry/statistics/R001_X001_Y007.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y007.tif', 'cytometry/statistics/R001_X002_Y007.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y007.tif', 'cytometry/statistics/R001_X003_Y007.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y008.tif', 'cytometry/statistics/R001_X003_Y008.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y008.tif', 'cytometry/statistics/R001_X002_Y008.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y008.tif', 'cytometry/statistics/R001_X001_Y008.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X001_Y009.tif', 'cytometry/statistics/R001_X001_Y009.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X002_Y009.tif', 'cytometry/statistics/R001_X002_Y009.csv')
# Saved cytometry data to paths  ('cytometry/tile/R001_X003_Y009.tif', 'cytometry/statistics/R001_X003_Y009.csv')

# %%
# Aggregate cell stats
ck_core.aggregate_cytometry_statistics(output_dir, config, mode='all')
# Out:
# ('/lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00/cytometry/data.csv',
#  '/lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00/cytometry/data.fcs')

# %% [markdown]
# #### Montage Results

# %%
img_mtg.shape, img_mtg.dtype
# Out:
# ((1, 7, 3, 9072, 4032), dtype('uint16'))

# %%
img_obj_border = img_obj * segmentation.find_boundaries(img_obj, mode='inner').astype(img_obj.dtype)
img_obj.shape, img_obj.dtype, img_obj_border.shape, img_obj_border.dtype
# Out:
# ((9072, 4032), dtype('int32'), (9072, 4032), dtype('int32'))

# %%
img_mtg_cell = ck_core.montage([v[1] for v in seg_res.values()], config)
img_mtg_cell.shape, img_mtg_cell.dtype
# Out:
# ((1, 7, 4, 9072, 4032), dtype('uint16'))

# %%
# Build montage with original channels, spheroid objects, and cell + nucleus objects
# * For now, save only boundaries and not full masks
assert img_mtg.dtype == np.uint16
mtg_channels = config.channel_names + ['SPHEROID_BOUNDARY', 'CELL_BOUNDARY', 'NUCLEUS_BOUNDARY']
img_mtg_exp = np.concatenate((
    img_mtg,
    repeat(img_obj_border, config.n_z_planes).astype(np.uint16),
    # repeat(img_obj, config.n_z_planes).astype(np.uint16),
    img_mtg_cell[:, :, [2,3]].astype(np.uint16)
), axis=2)
assert len(mtg_channels) == img_mtg_exp.shape[2]
describe(img_mtg_exp)
# Out:
# {'bytes': 3072577536,
#  'max': 65535,
#  'mean': 8775.356499764503,
#  'min': 0,
#  'shape': (1, 7, 6, 9072, 4032),
#  'type': 'uint16'}

# %%
mtg_channels
# Out:
# ['SYTOX',
#  'BF',
#  'HOECHST',
#  'SPHEROID_BOUNDARY',
#  'CELL_BOUNDARY',
#  'NUCLEUS_BOUNDARY']

# %%
path = osp.join(output_dir, ck_io.get_montage_image_path(0, 'segm'))
os.makedirs(osp.dirname(path), exist_ok=True)
tags = ij_utils.get_channel_label_tags(mtg_channels, z=config.n_z_planes, t=1)
ck_io.save_tile(path, img_mtg_exp, config=config, infer_labels=False, extratags=tags)
path
# Out:
# '/lab/data/spheroid/20190703-sta-titration/output/sta-00.500-20um-s-XY01/v00/montage/segm/R001.tif'
