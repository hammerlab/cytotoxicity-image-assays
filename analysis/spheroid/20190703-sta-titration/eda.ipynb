# %%
# %load_ext dotenv
# %dotenv env.sh
# %matplotlib inline
import pandas as pd
import numpy as np
import os
import os.path as osp
from cytokit import config as ck_config
from skimage import io
import matplotlib.pyplot as plt
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
data_dir = os.environ['EXP_GROUP_RAW_DIR']
img_dir = osp.join(data_dir, '0125uMsta-20um-grids', 'XY01')
img_dir
# Out:
# '/lab/data/spheroid/20190703-sta-titration/raw/0125uMsta-20um-grids/XY01'

# %%
img = io.imread(osp.join(img_dir, '1_XY01_00012_Z007_CH1.tif'))
img.dtype, img.shape
# Out:
# (dtype('uint16'), (1440, 1920, 3))

# %%
plt.imshow(img[..., 0])

# %%
img = io.imread(osp.join(img_dir, '1_XY01_00012_Z007_CH2.tif'))
img.dtype, img.shape
# Out:
# (dtype('uint16'), (1440, 1920))

# %%
plt.imshow(img)

# %%
img = io.imread(osp.join(img_dir, '1_XY01_00012_Z007_CH3.tif'))
img.dtype, img.shape
# Out:
# (dtype('uint16'), (1440, 1920))

# %%
plt.imshow(img)
