# %%
import os.path as osp
import os
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = io.imread('/lab/data/spheroid/20190719-co-culture/raw/20mioTcells-nopeptide/XY02/1_XY02_00017_Z008_CH2.tif')
img.shape, img.dtype
# Out:
# ((720, 960, 3), dtype('uint16'))

# %%
np.apply_over_axes(np.max, img, [0, 1])
# Out:
# array([[[   0, 9923,    0]]], dtype=uint16)

# %%
plt.imshow(img[..., 1])
