# %%
import pandas as pd
import numpy as np
import os.path as osp
import re
import glob
# %load_ext dotenv
# %dotenv env.sh
# %run -m cytokit_nb.keyence

# %%
df = pd.read_csv('experiments-base.csv')
df
# Out:
#              name                   dir
# 0   0000kT-0uM-np              noTcells
# 1   0000kT-4uM-np                4uMsta
# 2   0250kT-0uM-np  250kTcells-nopeptide
# 3   0500kT-0uM-np        500k-nopeptide
# 4   1000kT-0uM-np  1mioTcells-nopeptide
# 5   2000kT-0uM-np  2mioTcells-nopeptide
# 6   4000kT-0uM-np  4mioTcells-nopeptide
# 7   0250kT-0uM-wp    250kTcells-peptide
# 8   0500kT-0uM-wp    500kTcells-peptide
# 9   1000kT-0uM-wp    1mioTcells-peptide
# 10  2000kT-0uM-wp    2mioTcells-peptide
# 11  4000kT-0uM-wp    4mioTcells-peptide

# %%
def get_grids(r):
    grids = glob.glob(osp.join(os.environ['EXP_GROUP_RAW_DIR'], r['dir'], 'XY*')) 
    return [g.split(os.sep)[-1] for g in grids]
    
dfg = df.copy()
dfg['grid'] = df.apply(get_grids, axis=1)

# Stack grid list into rows
dfg = dfg.set_index(['name', 'dir'])['grid'].apply(pd.Series).stack().rename('grid').reset_index(level=-1, drop=True).reset_index()

# Assign replicate number
dfg = dfg.groupby(['name', 'dir'], group_keys=False)\
    .apply(lambda g: g.assign(rep=pd.Categorical(g['grid'], ordered=True, categories=g['grid'].sort_values()).codes + 1))
dfg.head()
# Out:
#             name       dir  grid  rep
# 0  0000kT-0uM-np  noTcells  XY01    1
# 1  0000kT-0uM-np  noTcells  XY02    2
# 2  0000kT-0uM-np  noTcells  XY03    3
# 3  0000kT-4uM-np    4uMsta  XY01    1
# 4  0000kT-4uM-np    4uMsta  XY02    2

# %%
dfg.groupby(['name', 'dir'])['grid'].unique()
# Out:
# name           dir
# 0000kT-0uM-np  noTcells                [XY01, XY02, XY03]
# 0000kT-4uM-np  4uMsta                  [XY01, XY02, XY03]
# 0250kT-0uM-np  250kTcells-nopeptide    [XY07, XY08, XY09]
# 0250kT-0uM-wp  250kTcells-peptide      [XY04, XY05, XY06]
# 0500kT-0uM-np  500k-nopeptide          [XY01, XY02, XY03]
# 0500kT-0uM-wp  500kTcells-peptide      [XY01, XY02, XY03]
# 1000kT-0uM-np  1mioTcells-nopeptide          [XY01, XY02]
# 1000kT-0uM-wp  1mioTcells-peptide      [XY01, XY02, XY03]
# 2000kT-0uM-np  2mioTcells-nopeptide    [XY01, XY02, XY03]
# 2000kT-0uM-wp  2mioTcells-peptide      [XY01, XY02, XY03]
# 4000kT-0uM-np  4mioTcells-nopeptide    [XY01, XY02, XY03]
# 4000kT-0uM-wp  4mioTcells-peptide      [XY01, XY02, XY03]
# Name: grid, dtype: object

# %%
dfg.groupby(['name', 'dir'])['rep'].unique()
# Out:
# name           dir
# 0000kT-0uM-np  noTcells                [1, 2, 3]
# 0000kT-4uM-np  4uMsta                  [1, 2, 3]
# 0250kT-0uM-np  250kTcells-nopeptide    [1, 2, 3]
# 0250kT-0uM-wp  250kTcells-peptide      [1, 2, 3]
# 0500kT-0uM-np  500k-nopeptide          [1, 2, 3]
# 0500kT-0uM-wp  500kTcells-peptide      [1, 2, 3]
# 1000kT-0uM-np  1mioTcells-nopeptide       [1, 2]
# 1000kT-0uM-wp  1mioTcells-peptide      [1, 2, 3]
# 2000kT-0uM-np  2mioTcells-nopeptide    [1, 2, 3]
# 2000kT-0uM-wp  2mioTcells-peptide      [1, 2, 3]
# 4000kT-0uM-np  4mioTcells-nopeptide    [1, 2, 3]
# 4000kT-0uM-wp  4mioTcells-peptide      [1, 2, 3]
# Name: rep, dtype: object

# %%
def get_row(r, info, base_conf):
    return r.append(pd.Series({
        'z_pitch': info['z_pitch'].iloc[0],
        'n_tiles': info['tile'].nunique(),
        'n_z': info['z'].nunique(),
        'n_ch': info['ch'].nunique(),
        'chs': tuple(sorted(info['ch'].unique())),
        'conf': 'experiment.yaml'
    })).sort_index()

def add_info(r):
    r = r.copy()
    path = osp.join(os.environ['EXP_GROUP_RAW_DIR'], r['dir'], r['grid'])
    info = analyze_keyence_dataset(path)
    base_conf = 'experiment.yaml'
    return get_row(r, info, base_conf)

dfi = pd.DataFrame([
    add_info(r)
    for _, r in dfg.iterrows()
])
dfi.head()
# Out:
#             chs             conf       dir  grid  n_ch  n_tiles  n_z  \
# 0  (1, 2, 3, 4)  experiment.yaml  noTcells  XY01     4       33    9
# 1  (1, 2, 3, 4)  experiment.yaml  noTcells  XY02     4       33    8
# 2  (1, 2, 3, 4)  experiment.yaml  noTcells  XY03     4       33    8
# 3  (1, 2, 3, 4)  experiment.yaml    4uMsta  XY01     4       33    7
# 4  (1, 2, 3, 4)  experiment.yaml    4uMsta  XY02     4       33   10
#
#             name  rep  z_pitch
# 0  0000kT-0uM-np    1      200
# 1  0000kT-0uM-np    2      200
# 2  0000kT-0uM-np    3      200
# 3  0000kT-4uM-np    1      200
# 4  0000kT-4uM-np    2      200

# %%
dfi['n_tiles'].unique()
# Out:
# array([33])

# %%
dfi['z_pitch'].unique()
# Out:
# array([200])

# %%
dfi['chs'].unique()
# Out:
# array([('1', '2', '3', '4')], dtype=object)

# %%
assert dfi['chs'].nunique() == 1
assert dfi['n_ch'].nunique() == 1
assert dfi['z_pitch'].nunique() == 1
assert dfi['n_tiles'].nunique() == 1

# %%
dfe = dfi.copy()
dfe = dfe.rename(columns={'name': 'cond'})
dfe = dfe.drop('chs', axis=1)
dfe.insert(0, 'name', dfe.apply(lambda r: '{}-{}-{}'.format(r['cond'], r['grid'], r['rep']), axis=1))
dfe.head()
# Out:
#                    name             conf       dir  grid  n_ch  n_tiles  n_z  \
# 0  0000kT-0uM-np-XY01-1  experiment.yaml  noTcells  XY01     4       33    9
# 1  0000kT-0uM-np-XY02-2  experiment.yaml  noTcells  XY02     4       33    8
# 2  0000kT-0uM-np-XY03-3  experiment.yaml  noTcells  XY03     4       33    8
# 3  0000kT-4uM-np-XY01-1  experiment.yaml    4uMsta  XY01     4       33    7
# 4  0000kT-4uM-np-XY02-2  experiment.yaml    4uMsta  XY02     4       33   10
#
#             cond  rep  z_pitch
# 0  0000kT-0uM-np    1      200
# 1  0000kT-0uM-np    2      200
# 2  0000kT-0uM-np    3      200
# 3  0000kT-4uM-np    1      200
# 4  0000kT-4uM-np    2      200

# %%
dfe
# Out:
#                     name             conf                   dir  grid  n_ch  \
# 0   0000kT-0uM-np-XY01-1  experiment.yaml              noTcells  XY01     4
# 1   0000kT-0uM-np-XY02-2  experiment.yaml              noTcells  XY02     4
# 2   0000kT-0uM-np-XY03-3  experiment.yaml              noTcells  XY03     4
# 3   0000kT-4uM-np-XY01-1  experiment.yaml                4uMsta  XY01     4
# 4   0000kT-4uM-np-XY02-2  experiment.yaml                4uMsta  XY02     4
# 5   0000kT-4uM-np-XY03-3  experiment.yaml                4uMsta  XY03     4
# 6   0250kT-0uM-np-XY07-1  experiment.yaml  250kTcells-nopeptide  XY07     4
# 7   0250kT-0uM-np-XY08-2  experiment.yaml  250kTcells-nopeptide  XY08     4
# 8   0250kT-0uM-np-XY09-3  experiment.yaml  250kTcells-nopeptide  XY09     4
# 9   0250kT-0uM-wp-XY04-1  experiment.yaml    250kTcells-peptide  XY04     4
# 10  0250kT-0uM-wp-XY05-2  experiment.yaml    250kTcells-peptide  XY05     4
# 11  0250kT-0uM-wp-XY06-3  experiment.yaml    250kTcells-peptide  XY06     4
# 12  0500kT-0uM-np-XY01-1  experiment.yaml        500k-nopeptide  XY01     4
# 13  0500kT-0uM-np-XY02-2  experiment.yaml        500k-nopeptide  XY02     4
# 14  0500kT-0uM-np-XY03-3  experiment.yaml        500k-nopeptide  XY03     4
# 15  0500kT-0uM-wp-XY01-1  experiment.yaml    500kTcells-peptide  XY01     4
# 16  0500kT-0uM-wp-XY02-2  experiment.yaml    500kTcells-peptide  XY02     4
# 17  0500kT-0uM-wp-XY03-3  experiment.yaml    500kTcells-peptide  XY03     4
# 18  1000kT-0uM-np-XY01-1  experiment.yaml  1mioTcells-nopeptide  XY01     4
# 19  1000kT-0uM-np-XY02-2  experiment.yaml  1mioTcells-nopeptide  XY02     4
# 20  1000kT-0uM-wp-XY01-1  experiment.yaml    1mioTcells-peptide  XY01     4
# 21  1000kT-0uM-wp-XY02-2  experiment.yaml    1mioTcells-peptide  XY02     4
# 22  1000kT-0uM-wp-XY03-3  experiment.yaml    1mioTcells-peptide  XY03     4
# 23  2000kT-0uM-np-XY01-1  experiment.yaml  2mioTcells-nopeptide  XY01     4
# 24  2000kT-0uM-np-XY02-2  experiment.yaml  2mioTcells-nopeptide  XY02     4
# 25  2000kT-0uM-np-XY03-3  experiment.yaml  2mioTcells-nopeptide  XY03     4
# 26  2000kT-0uM-wp-XY01-1  experiment.yaml    2mioTcells-peptide  XY01     4
# 27  2000kT-0uM-wp-XY02-2  experiment.yaml    2mioTcells-peptide  XY02     4
# 28  2000kT-0uM-wp-XY03-3  experiment.yaml    2mioTcells-peptide  XY03     4
# 29  4000kT-0uM-np-XY01-1  experiment.yaml  4mioTcells-nopeptide  XY01     4
# 30  4000kT-0uM-np-XY02-2  experiment.yaml  4mioTcells-nopeptide  XY02     4
# 31  4000kT-0uM-np-XY03-3  experiment.yaml  4mioTcells-nopeptide  XY03     4
# 32  4000kT-0uM-wp-XY01-1  experiment.yaml    4mioTcells-peptide  XY01     4
# 33  4000kT-0uM-wp-XY02-2  experiment.yaml    4mioTcells-peptide  XY02     4
# 34  4000kT-0uM-wp-XY03-3  experiment.yaml    4mioTcells-peptide  XY03     4
#
#     n_tiles  n_z           cond  rep  z_pitch
# 0        33    9  0000kT-0uM-np    1      200
# 1        33    8  0000kT-0uM-np    2      200
# 2        33    8  0000kT-0uM-np    3      200
# 3        33    7  0000kT-4uM-np    1      200
# 4        33   10  0000kT-4uM-np    2      200
# 5        33    7  0000kT-4uM-np    3      200
# 6        33    8  0250kT-0uM-np    1      200
# 7        33    9  0250kT-0uM-np    2      200
# 8        33    7  0250kT-0uM-np    3      200
# 9        33   10  0250kT-0uM-wp    1      200
# 10       33    8  0250kT-0uM-wp    2      200
# 11       33    8  0250kT-0uM-wp    3      200
# 12       33    7  0500kT-0uM-np    1      200
# 13       33    8  0500kT-0uM-np    2      200
# 14       33    8  0500kT-0uM-np    3      200
# 15       33    7  0500kT-0uM-wp    1      200
# 16       33    7  0500kT-0uM-wp    2      200
# 17       33    9  0500kT-0uM-wp    3      200
# 18       33    7  1000kT-0uM-np    1      200
# 19       33    9  1000kT-0uM-np    2      200
# 20       33    7  1000kT-0uM-wp    1      200
# 21       33    8  1000kT-0uM-wp    2      200
# 22       33    7  1000kT-0uM-wp    3      200
# 23       33    8  2000kT-0uM-np    1      200
# 24       33    7  2000kT-0uM-np    2      200
# 25       33    8  2000kT-0uM-np    3      200
# 26       33    9  2000kT-0uM-wp    1      200
# 27       33    8  2000kT-0uM-wp    2      200
# 28       33    7  2000kT-0uM-wp    3      200
# 29       33    8  4000kT-0uM-np    1      200
# 30       33    8  4000kT-0uM-np    2      200
# 31       33    9  4000kT-0uM-np    3      200
# 32       33    8  4000kT-0uM-wp    1      200
# 33       33    9  4000kT-0uM-wp    2      200
# 34       33    8  4000kT-0uM-wp    3      200

# %%
dfe.to_csv('experiments.csv', index=False)
