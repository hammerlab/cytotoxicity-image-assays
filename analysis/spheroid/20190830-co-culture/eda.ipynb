# %%
import os.path as osp
import os
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = io.imread('/lab/data/spheroid/20190822-co-culture/raw/250kTcells-nopeptide/XY07/1_XY07_00016_Z007_CH3.tif')
img.shape, img.dtype
# Out:
# ((1440, 1920), dtype('uint16'))

# %%
np.apply_over_axes(np.max, img, [0, 1])
# Out:
# array([[65535]], dtype=uint16)

# %%
plt.imshow(img)

# %%
plt.imshow(img[..., 0])
